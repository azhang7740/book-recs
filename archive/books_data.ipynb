# %%
# taking a look at the data
import pandas as pd

books = pd.read_csv('Books Data/books.csv')
ratings = pd.read_csv('Books Data/ratings.csv')
tags = pd.read_csv('Books Data/tags.csv')
to_read = pd.read_csv('Books Data/to_read.csv')

over_fifty_ratings = pd.read_csv('over_fifty_ratings.csv')
over_hundred_ratings = pd.read_csv('over_hundred_ratings.csv')
short_books = pd.read_csv('short_books.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# ...

# %%
ratings.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
ratings_column = ratings['rating']
type(ratings_column)
# Out:
# pandas.core.series.Series

# %%
ratings_column.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
rating_distribution = rating_distribution['work_ratings_count']
rating_distribution.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ratings
# Out:
#          user_id  book_id  rating
# 0              1      258       5
# 1              2     4081       4
# 2              2      260       5
# 3              2     9296       5
# 4              2     2318       3
# ...          ...      ...     ...
# 5976474    49925      510       5
# 5976475    49925      528       4
# 5976476    49925      722       4
# 5976477    49925      949       5
# 5976478    49925     1023       4
#
# [5976479 rows x 3 columns]

# %%
to_read.sort_values(by="user_id", inplace=True)

# %%
to_read
# Out:
#         user_id  book_id
# 614750        1      235
# 775761        1     2058
# 581413        1     1874
# 775760        1      112
# 775759        1      533
# ...         ...      ...
# 746357    53424     8859
# 746355    53424      778
# 746352    53424     4844
# 744779    53424     1512
# 746356    53424     5907
#
# [912705 rows x 2 columns]

# %%
tags
# Out:
#        tag_id    tag_name
# 0           0           -
# 1           1        --1-
# 2           2       --10-
# 3           3       --12-
# 4           4      --122-
# ...       ...         ...
# 34247   34247   Ｃhildrens
# 34248   34248   Ｆａｖｏｒｉｔｅｓ
# 34249   34249       Ｍａｎｇａ
# 34250   34250      ＳＥＲＩＥＳ
# 34251   34251  ｆａｖｏｕｒｉｔｅｓ
#
# [34252 rows x 2 columns]

# %%
book_tags = pd.read_csv( 'Books Data/book_tags.csv')

# %%
book_tags
# Out:
#         goodreads_book_id  tag_id   count
# 0                       1   30574  167697
# 1                       1   11305   37174
# 2                       1   11557   34173
# 3                       1    8717   12986
# 4                       1   33114   12716
# ...                   ...     ...     ...
# 999907           33288638   21303       7
# 999908           33288638   17271       7
# 999909           33288638    1126       7
# 999910           33288638   11478       7
# 999911           33288638   27939       7
#
# [999912 rows x 3 columns]
